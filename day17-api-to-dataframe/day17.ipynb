# %%
import pandas as pd
import requests
import time

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#        id                        title  \
# 0   19404  Dilwale Dulhania Le Jayenge
# 1  724089    Gabriel's Inferno Part II
# 2     278     The Shawshank Redemption
# 3     238                The Godfather
# 4  761053   Gabriel's Inferno Part III
#
#                                             overview release_date  popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      18.433
# 1  Professor Gabriel Emerson finally learns the t...   2020-07-31       8.439
# 2  Framed in the 1940s for the double murder of h...   1994-09-23      65.570
# 3  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14      63.277
# 4  The final part of the film adaption of the ero...   2020-11-19      26.691
#
#    vote_average  vote_count
# 0           8.7        2763
# 1           8.7        1223
# 2           8.7       18637
# 3           8.7       14052
# 4           8.7         773

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,400):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)  # Here i used time sleep because too frequent api hit cause problem  and i have total page size 519 so i can maximise my row
    time.sleep(0.25)

# %%
df
# Out:
#            id                     title  \
# 0         278  The Shawshank Redemption
# 1         238             The Godfather
# 2         240     The Godfather Part II
# 3         424          Schindler's List
# 4         389              12 Angry Men
# ...       ...                       ...
# 7975  1051896                  Arcadian
# 7976   437670      Suck Me Shakespeer 3
# 7977   383709              Wonderstruck
# 7978   119283                    Parker
# 7979     9085             Harlem Nights
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 7975  In the near future, on a decimated Earth, Paul...   2024-04-12
# 7976  A bank robber becomes a teacher after being re...   2017-10-26
# 7977  The story of a young boy in the Midwest is tol...   2017-10-13
# 7978  A thief with a unique code of professional eth...   2013-01-23
# 7979  'Sugar' Ray is the owner of an illegal casino ...   1989-11-17
#
#       popularity  vote_average  vote_count
# 0        28.6613         8.713       28947
# 1        28.7339         8.686       21878
# 2        17.1534         8.571       13218
# 3        13.0232         8.566       16733
# 4        12.2075         8.548        9424
# ...          ...           ...         ...
# 7975      6.7296         6.069         742
# 7976      3.1888         6.069         474
# 7977      2.9993         6.100         419
# 7978      6.0648         6.069        3146
# 7979      1.5446         6.069         328
#
# [7980 rows x 7 columns]

# %%
df.shape
# Out:
# (7980, 7)

# %%
df.to_csv('movies.csv')
